# %%
# import library ที่จำเป็น
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# อ่านข้อมูล test
data = pd.read_csv('test.csv')
print('data = ', len(data))

# %%
# เนื่องจากค่าจาก test ตรวจสอบแล้วไม่พบปัญหาจึงไม่จำเป็นต้องคลีน data ที่มีปัญหา และไม่ต้องคำนวณ surface area เพิ่ม

# %%
# นิยามฟังก์ชั่นสำหรับคำนวณ density และ แยก functional groups
# โดยกรณี functional_groups นั้นพบ NaN แต่ก็พบใน pretest เช่นกัน จึงคงไว้ไม่ตัดออก

def cal_density(df):
    return (df["weight [u]"] / df["volume [A^3]"]) * 1.66054

def split_functional_groups(a):
    return (a.split("-") + [' ', ' '])[:2]

data['functional_groups'] = data['functional_groups'].replace([np.nan], [" "])
data['functional_groups-1'] = data['functional_groups'].apply(split_functional_groups).map(lambda x:x[0])
data['functional_groups-2'] = data['functional_groups'].apply(split_functional_groups).map(lambda x:x[1])

data['density [g/cm^3]'] = cal_density(data)
data['density [cm^3/g]'] = 1./cal_density(data)

# %%
# รวมไฟล์ที่เกิดจากการคำนวณฟีเจอร์ต่างๆ

structure_data = pd.read_csv('test_features_full.csv')
# structure_data = structure_data.drop(['n_ol1', 'n_ol2', 'n_fg1', 'n_fg2'], axis=1)
final = pd.merge(data, structure_data, on="MOFname")

RDF_data = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF.csv')
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_1.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_4_6_8_12.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_15_25.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_22_24.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_14_16_18.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_3_5_7_9.csv')
RDF_data_R = RDF_data_R.drop(['RDF-5-1', 'RDF-5-2', 'RDF-5-3'], 1)
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_11_13_17_19.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_21_26_28.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_23_27_29.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")

RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_2_3_4_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_5_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_6_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_7_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_8_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_9_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_10_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")

RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_11_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_12_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_13_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_14_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")

RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_15_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_16_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_17_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_18_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_19_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_20_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_21_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_22_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_23_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_24_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_25_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_26_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_27_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_28_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_29_p5.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_2_p_2.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_2_p_8.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_3_p_2.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")
RDF_data_R = pd.read_csv('/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_features_RDF_R_3_p_8.csv')
RDF_data = pd.merge(RDF_data, RDF_data_R, on="MOFname")


final_test = pd.merge(final, RDF_data, on="MOFname")
print(len(data), len(final))

# %%
final.to_csv(f'/mnt/c/Users/Cue/Desktop/tmlcc-2021/test_fixed.csv', index=False)
